# %% [markdown]
# <a href="https://colab.research.google.com/github/xXCraftyKingXx/fa3program-/blob/main/fa3programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#fa3prog1
name = input("Enter student's name: ")
age = int(input("Enter student's age: "))
course = str(input("Enter student's course: "))
print ("/n---Student Information---")
print ("Name:", name)
print ("Age:", age)
print ("Course:", course)
# Out:
# Enter student's name: Jett
# Enter student's age: 13
# Enter student's course: Doctor
# /n---Student Information---
# Name: Jett
# Age: 13
# Course: Doctor

# %%
#fa3prog2
exam_scores = int(input("Enter exam score: "))
if exam_scores >= 75:
    print("Passed")

elif exam_scores < 75:
    print("Failed")
# Out:
# Enter exam score: 76
# Passed

# %%
#fa3prog3
name = input("Enter student's name: ")
score = float(input("Enter student's score: "))
if score >= 90:
  grade = "A"
elif score >= 80:
  grade = "B"
elif score >= 70:
  grade = "C"
else:
  grade = "F"

print(f"Output: {grade}")
# Out:
# Enter student's name: Jett
# Enter student's score: 91
# Output: A
